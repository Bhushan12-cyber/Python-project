# %% [markdown]
# # Basics of Probability

# %% [markdown]
# Question 1. (a)

# %%
import random
heads = tails = 0
for _ in range(10000):
    if random.choice(['H','T']) == 'H':
        heads += 1
    else:
        tails += 1
print("Heads : ",heads)
print("Tails : ",tails)
# Out:
# Heads :  4986
# Tails :  5014

# %% [raw]
# We can see that by using random.choice we are simulating Heads and tails probability in coin flipping

# %% [markdown]
# Question 1. (b)

# %%
sum = 0
for _ in range(10000):
    if random.randint(1,6) + random.randint(1,6) == 7:
        sum += 1;
print("Probabilit of sum 7 :", sum/10000)
# Out:
# Probabilit of sum 7 : 0.1632

# %% [raw]
# Here we have used random.randint two times to simulate two dice

# %% [markdown]
# Question 2.

# %%
def prob_for_six(trials):
    count = 0
    for _ in range(trials):
        if 6 in [random.randint(1,6) for _ in range(10)]:
            count+=1
    return count / trials

print("Probability of getting six : ", prob_for_six(10000))
# Out:
# Probability of getting six :  0.8391

# %% [markdown]
# # Conditional Probability and Bayes Theorem

# %% [markdown]
# Question 3. (a)

# %%
color = ['red']*5 + ['green']*7 + ['blue']*8
cnt_bl = 0
red_given_bl = 0
prev_color = None
for _ in range(1000):
    current = random.choice(color)
    if prev_color == 'blue':
        cnt_bl += 1
    if current == 'red':
        red_given_bl += 1
    prev_color = current
print("probability of drawing a red ball given that the previous ball was blue is: ", red_given_bl / cnt_bl)
# Out:
# probability of drawing a red ball given that the previous ball was blue is:  0.6139088729016786

# %% [raw]
# We repeatedly picked a ball from the bag, noted its color, and then put it back before the next draw—just like how you'd do it in real life. Then, we looked at how often a red ball was picked right after a blue one. By counting those cases, we figured out the actual probability based on what happened during the simulation.

# %% [markdown]
# # Random Variables and Discrete Probability

# %%
import numpy as np
values = [1,2,3]
probs = [0.25,0.35,0.4]
sample = np.random.choice(values , size = 1000 , p = probs)
print("Mean: ",np.mean(sample))
print("Variance: ", np.var(sample))
print("standard deviation: ", np.std(sample))
# Out:
# Mean:  2.162
# Variance:  0.6437560000000001
# standard deviation:  0.8023440658470654

# %% [raw]
# by using inbuilt numpy like mean, var, std we can calculate statitics easily

# %% [markdown]
# # Continuous Random Variables

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data = np.random.exponential(scale = 5 , size = 2000)
sns.histplot(data, bins = 30 , kde = True)
plt.title("Exponential distribution")
plt.xlabel("Val")
plt.ylabel("Freq")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'Freq')

# %% [raw]
# kde = true gives us the line in the graph

# %% [markdown]
# # Central Limit Theorem

# %%
uniform_d = np.random.uniform(0,1,10000)
sample_mean = []
for _ in range(1000):
    sample = np.random.choice(uniform_d, size = 30)
    sample_mean.append(np.mean(sample))
plt .subplot(1,2,1)
sns.histplot(uniform_d , bins=30, kde =True)
plt.title("Uniform distribution")
plt .subplot(1,2,2)
sns.histplot(sample_mean , bins=30, kde =True)
plt.title("Sample mean distribution")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Sample mean distribution')

# %% [raw]
# here the sample mean distribution is also looking normal
